# %%
import os
from datasets import load_from_disk

query_config="LitSearch_query"

print(os.getcwd()) 
project_root = "/home/olagh48652/irg_course_assig/irg_final_project"

dataset_dir = os.path.join(project_root, "dataset")

query_path = os.path.join(dataset_dir, query_config)

dataset_query = load_from_disk(query_path)
# Out:
# /home/olagh48652/irg_course_assig/irg_final_project/src/getting_started

# %%
for ind, qline in enumerate(dataset_query['full']):
    query_text = qline['query']
    print("query_text: ", query_text)
    print("type query_text: ", type(query_text))
# Out:
# query_text:  Are there any research papers on methods to compress large-scale language models using task-agnostic knowledge distillation techniques?
# type query_text:  <class 'str'>
# query_text:  Are there any resources available for translating Tunisian Arabic dialect that contain both manually translated comments by native speakers and additional data augmented through methods like segmentation at stop words level?
# type query_text:  <class 'str'>
# query_text:  Are there any studies that explore post-hoc techniques for hallucination detection at both the token- and sentence-level in neural sequence generation tasks?
# type query_text:  <class 'str'>
# query_text:  Are there any tools or studies that have focused on building a morphological analyzer specifically for handling multiple Arabic dialects?
# type query_text:  <class 'str'>
# query_text:  Are there papers that propose contextualized calibration for the probability of answers in language models?
# ...

# %%
dataset_query['full']
# Out:
# Dataset({
#     features: ['query_set', 'query', 'specificity', 'quality', 'corpusids'],
#     num_rows: 597
# })
